# %%
# Import Libaries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
# Load Data Sets

df = pd.read_csv('BigBasket Products.csv')

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# ### **Data Exploration:**

# %%
# Description about the data

df.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %%
# information about the data.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
# use head function to look first 12 rows.

df.head(12)
# Out:
#     index                                            product  \
# 0       1             Garlic Oil - Vegetarian Capsule 500 mg
# 1       2                              Water Bottle - Orange
# 2       3                     Brass Angle Deep - Plain, No.2
# 3       4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4       5                 Creme Soft Soap - For Hands & Body
# 5       6                  Germ - Removal Multipurpose Wipes
# 6       7                                       Multani Mati
# 7       8                  Hand Sanitizer - 70% Alcohol Base
# 8       9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9      10               Scrub Pad - Anti- Bacterial, Regular
# 10     11                           Wheat Grass Powder - Raw
# 11     12                     Butter Cookies Gold Collection
#
#                   category            sub_category              brand  \
# 0         Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# ...

# %%
df.tail(10)
# Out:
#        index                                          product  \
# 27545  27546  Toilet Cleaning Brush - Round With Holder (Big)
# 27546  27547                    Organic Powder - Garam Masala
# 27547  27548                                  Powder - Baking
# 27548  27549                      Apple Cider Vinegar Shampoo
# 27549  27550                             Papad - Garlic Disco
# 27550  27551       Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                         Rosemary
# 27552  27553                     Peri-Peri Sweet Potato Chips
# 27553  27554                        Green Tea - Pure Original
# 27554  27555                   United Dreams Go Far Deodorant
#
#                        category              sub_category  \
# 27545      Cleaning & Household    Mops, Brushes & Scrubs
# 27546  Foodgrains, Oil & Masala           Organic Staples
# 27547    Snacks & Branded Foods       Ready To Cook & Eat
# ...

# %% [markdown]
# ### **Cleaning Data:**

# %%
# Finding null values in data Frame

df.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# dtype: int64

# %%
#Total Null Values
df.isnull().sum().sum()
# Out:
# 8759

# %%
# find the outliers from the datasets and cleaning data

# %%
sns.boxplot(df.sale_price,orient='h')
# Out:
# <Axes: >

# %%
# Checking sale price more than 10000
df[df.sale_price>10000]
# Out:
#        index                                            product  \
# 248      249  4mm Aluminium Induction Base Chapati Roti Tawa...
# 288      289          Arrabbiata Tomato Pasta Sauce With Chilli
# 436      437                       Balloon - Polka Dot, 12 Inch
# 1249    1250                                          Beard Kit
# 21761  21762      Pet Food - N&D Team Breeder Puppy Top Farmina
# 25301  25302                                    Bravura Clipper
#
#                      category            sub_category       brand  sale_price  \
# 248    Kitchen, Garden & Pets    Cookware & Non Stick       HAZEL    111649.0
# 288      Gourmet & World Food  Sauces, Spreads & Dips   Montanini     22325.0
# 436      Cleaning & Household   Party & Festive Needs    B Vishal     88899.0
# 1249         Beauty & Hygiene          Men's Grooming  Uncle Tony    112475.0
# 21761  Kitchen, Garden & Pets  Pet Food & Accessories     Farmina     10090.0
# ...

# %%
#Fill Correct amount after checked market price

# %%
df.sale_price=np.where(df.sale_price==22325.0,325.0,df.sale_price)

# %%
df.sale_price=np.where(df.sale_price==111649.0,1289.0,df.sale_price)

# %%
df.sale_price=np.where(df.sale_price==88899.0,129.0,df.sale_price)

# %%
df.sale_price=np.where(df.sale_price==112475.0,3300.0,df.sale_price)

# %%
df[df.sale_price>10000]
# Out:
#        index                                        product  \
# 21761  21762  Pet Food - N&D Team Breeder Puppy Top Farmina
# 25301  25302                                Bravura Clipper
#
#                      category            sub_category    brand  sale_price  \
# 21761  Kitchen, Garden & Pets  Pet Food & Accessories  Farmina     10090.0
# 25301  Kitchen, Garden & Pets  Pet Food & Accessories     Wahl     12500.0
#
#        market_price                     type  rating  \
# 21761       10090.0       Pet Meals & Treats     NaN
# 25301       12500.0  Pet Cleaning & Grooming     NaN
#
#                                              description
# 21761        Dog Food Adult Health Nutritional Dog Food.
# 25301  The bravura clipper is a must-have clipper for...

# %%
#Checking Null Values in Sale_price Columns

df[df.sale_price.isnull()]
# Out:
#       index                                            product  \
# 1719   1720            Puja Flower Wicks - Puvvu Vathulu Batti
# 1720   1721                                    Powder - Sambar
# 1721   1722  Steel Fork - Medium, Premium Excel Series, BBCL08
# 1722   1723                                 Snack Mix - Dhokla
# 2401   2402                              Battery AA 3UT Hi Top
# 2402   2403        Klassic Plain Cocktail Napkins (22 X 22 cm)
#
#                       category              sub_category       brand  \
# 1719      Cleaning & Household               Pooja Needs        Jaji
# 1720  Foodgrains, Oil & Masala          Masalas & Spices  Annapoorna
# 1721    Kitchen, Garden & Pets        Crockery & Cutlery     BB Home
# 1722    Snacks & Branded Foods       Ready To Cook & Eat         MTR
# 2401    Kitchen, Garden & Pets  Appliances & Electricals       Nippo
# 2402      Cleaning & Household  Disposables, Garbage Bag     Origami
#
# ...

# %%
#Fill null values in sale_price columns from Market_price columns

df.sale_price = df.sale_price.fillna(df.market_price)

# %%
#Checking Null Values now.

df.iloc[1718:1724]
# Out:
#       index                                            product  \
# 1718   1719                                     Samosa Chutney
# 1719   1720            Puja Flower Wicks - Puvvu Vathulu Batti
# 1720   1721                                    Powder - Sambar
# 1721   1722  Steel Fork - Medium, Premium Excel Series, BBCL08
# 1722   1723                                 Snack Mix - Dhokla
# 1723   1724  Masala Combo - Chicken 15 Gm + Meat 15 Gm + Pu...
#
#                       category         sub_category            brand  \
# 1718    Snacks & Branded Foods    Pickles & Chutney  Mother's Recipe
# 1719      Cleaning & Household          Pooja Needs             Jaji
# 1720  Foodgrains, Oil & Masala     Masalas & Spices       Annapoorna
# 1721    Kitchen, Garden & Pets   Crockery & Cutlery          BB Home
# 1722    Snacks & Branded Foods  Ready To Cook & Eat              MTR
# 1723  Foodgrains, Oil & Masala     Masalas & Spices         Kohinoor
#
# ...

# %%
# Final check null values in sale_price columns
df.sale_price.isnull().sum()
# Out:
# 0

# %%
# Handle missing values in 'product' and 'brand'
df['product'].fillna('Unknown Product',inplace=True)
df['brand'].fillna('Unknown Brand',inplace=True)

# Handle missing values in 'rating' by imputing with the median
df['rating'].fillna(df['rating'].median(),inplace=True)

# Handle missing values in 'description' by replacing with an empty string
df['description'].fillna('',inplace=True)

# %%
#Checking Null Values now
df.isnull().sum()
# Out:
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %% [markdown]
# ### ***Exploratory Data Analysis:***

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %% [markdown]
# ### ***Calculate Revenue:***

# %%
# Calculate total revenue
total_revenue = df['sale_price'].sum()

print(f'Total Revenue: Rs.{total_revenue:.2f}')
# Out:
# Total Revenue: Rs.8888560.73

# %%
# Group by category and subcategory and calculate total revenue for each group
category_revenue = df.groupby(['category', 'sub_category'])['sale_price'].sum().reset_index()

# %%
category_revenue
# Out:
#                   category               sub_category  sale_price
# 0                Baby Care       Atta, Flours & Sooji      300.00
# 1                Baby Care           Baby Accessories    15157.00
# 2                Baby Care        Baby Bath & Hygiene    86332.27
# 3                Baby Care        Baby Food & Formula    16974.15
# 4                Baby Care            Diapers & Wipes   183251.76
# ..                     ...                        ...         ...
# 94  Snacks & Branded Foods  Noodle, Pasta, Vermicelli     8762.36
# 95  Snacks & Branded Foods          Pickles & Chutney    20245.11
# 96  Snacks & Branded Foods        Ready To Cook & Eat    58615.50
# 97  Snacks & Branded Foods           Snacks & Namkeen    33674.89
# 98  Snacks & Branded Foods   Spreads, Sauces, Ketchup    67417.69
#
# [99 rows x 3 columns]

# %% [markdown]
# ### ***Count Categories:***

# %%
x = pd.DataFrame(df.groupby('sub_category')['sale_price'].sum().sort_values()).reset_index()
y = pd.DataFrame(df.groupby('sub_category')['sale_price'].count().sort_values()).reset_index()
x.rename(columns={'sale_price':'sale_prices'},inplace=True)
z = pd.DataFrame({'Sub Category':x.sub_category,'Sum of Prices':x.sale_prices,
                  'Count of Categories':y.sale_price})

# %%
z
# Out:
#                    Sub Category  Sum of Prices  Count of Categories
# 0                     Marinades         225.00                    1
# 1      Flower Bouquets, Bunches         666.00                    5
# 2            Herbs & Seasonings         745.93                    8
# 3            Pork & Other Meats        1315.00                   17
# 4   Organic Fruits & Vegetables        2356.50                   20
# ..                          ...            ...                  ...
# 85            Health & Medicine      414334.12                 1000
# 86         Cookware & Non Stick      427163.90                 1015
# 87           Crockery & Cutlery      465404.00                 1028
# 88            Fragrances & Deos      893099.59                 1133
# 89                    Skin Care      945427.58                 2294
#
# [90 rows x 3 columns]

# %% [markdown]
# ### **Pie Chart for Product Categories:**

# %%
# Pie chart to visualize the distribution of products across categories
category_counts = df['category'].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Products Across Categories')
plt.show()

# %% [markdown]
# ### ***Category-wise Sales:***

# %%
# Bar plot to show category-wise sales
plt.figure(figsize=(12, 6))
sns.countplot(y='category', data=df, order=df['category'].value_counts().index)
plt.title('Category-wise Sales')
plt.xlabel('Count')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# ###  **Distribution of Sale Prices:**

# %%
# Distribution of sale price

plt.figure(figsize=(10,6))
sns.histplot(df['sale_price'],bins=60,kde=True)
plt.title('Distribution of sale Price')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### ***Market Price vs Sale Price Comparison:***

# %%
# Scatter plot to compare market_price and sale_price
plt.figure(figsize=(10, 6))
sns.scatterplot(x='market_price', y='sale_price', data=df)
plt.title('Market Price vs. Sale Price Comparison')
plt.xlabel('Market Price')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
# ### ***Regression Plot: Sale Price vs Market Price:***

# %%
plt.figure(figsize=(10,6))
sns.regplot(y='sale_price',x='market_price',data =df)
plt.title('Regression Plot: Sale Price vs Market Price')
plt.xlabel('Market Price')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
# ###  **Category-wise Distribution of Ratings:**

# %%
# Calculate the average rating for products in each category
avg_rating_by_category = pd.DataFrame(df.groupby('category')['rating'].mean())

print('Average Rating by Category:')
print(avg_rating_by_category)
# Out:
# Average Rating by Category:
#                             rating
# category
# Baby Care                 4.038033
# Bakery, Cakes & Dairy     3.952409
# Beauty & Hygiene          3.982306
# Beverages                 4.089153
# Cleaning & Household      3.987439
# Eggs, Meat & Fish         4.100000
# Foodgrains, Oil & Masala  4.069021
# Fruits & Vegetables       4.100000
# Gourmet & World Food      4.040853
# Kitchen, Garden & Pets    3.844162
# Snacks & Branded Foods    3.997477

# %%
# Count plot to show the distribution of ratings
plt.figure(figsize=(10, 6))
sns.countplot(x='rating', data=df)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
#Creating Discount Columns

# %%
df['Discount'] = df.market_price-df.sale_price

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %% [markdown]
# ###  **Relationship between Sale Price and Discount:**

# %%
sns.scatterplot(x='Discount',y='sale_price',data=df)
plt.title('Relationship between Sale Price and Discount')
plt.xlabel('Discount')
plt.ylabel('sale price')
plt.show()

# %%
#Checking product price greater than 3000
df[df.Discount>3000]
# Out:
#                                                  product  \
# 1056   Gas Stove-3 Burner Royale Plus Schott Glass, B...
# 1789   Induction Base Non Stick Cookware Set With Gla...
# 2343   Induction Base Non Stick Cookware Set With Gla...
# 8759   Dinner Set - Laser Etched, Premium Stainless S...
# 21930  Premium Cloth Dryer/Drying Stand - Foldable, S...
# 23082  Gas Stove-4 Burner Royale Plus Schott Glass, B...
#
#                      category           sub_category               brand  \
# 1056   Kitchen, Garden & Pets   Cookware & Non Stick            Prestige
# 1789   Kitchen, Garden & Pets   Cookware & Non Stick              Nirlon
# 2343   Kitchen, Garden & Pets   Cookware & Non Stick              Nirlon
# 8759   Kitchen, Garden & Pets         Steel Utensils  Classic Essentials
# 21930  Kitchen, Garden & Pets  Storage & Accessories                  DP
# 23082  Kitchen, Garden & Pets   Cookware & Non Stick            Prestige
#
# ...

# %% [markdown]
# ### **Category wise Discount**:

# %%
# Category wise Discount
MRP= df.groupby('category')['market_price'].sum()
SRP =df.groupby('category')['sale_price'].sum()
(MRP-SRP)/MRP * 100
# Out:
# category
# Baby Care                   10.357351
# Bakery, Cakes & Dairy        9.550570
# Beauty & Hygiene            15.145428
# Beverages                   11.929061
# Cleaning & Household        13.707083
# Eggs, Meat & Fish           11.336396
# Foodgrains, Oil & Masala    16.062272
# Fruits & Vegetables         21.020576
# Gourmet & World Food        10.760220
# Kitchen, Garden & Pets      23.029183
# Snacks & Branded Foods       7.943227
# dtype: float64

# %%
MRP = pd.DataFrame(MRP).reset_index()
SRP = pd.DataFrame(SRP).reset_index()
Dis = pd.DataFrame({'category':MRP.category, 'Original Price':MRP.market_price,
                    'Sale Price':SRP.sale_price, 'Discount Price':MRP.market_price-SRP.sale_price,
                    'Disount Percent':(MRP.market_price-SRP.sale_price)/MRP.market_price*100
})

# %%
Dis
# Out:
#                     category  Original Price  Sale Price  Discount Price  \
# 0                  Baby Care       364020.00   326317.17        37702.83
# 1      Bakery, Cakes & Dairy       134357.00   121525.14        12831.86
# 2           Beauty & Hygiene      3882642.22  3294599.44       588042.78
# 3                  Beverages       240927.00   212186.67        28740.33
# 4       Cleaning & Household       701150.35   605043.09        96107.26
# 5          Eggs, Meat & Fish       114042.42   101114.12        12928.30
# 6   Foodgrains, Oil & Masala       615833.00   516916.23        98916.77
# 7        Fruits & Vegetables        35889.55    28345.36         7544.19
# 8       Gourmet & World Food      1680993.95  1500115.31       180878.64
# 9     Kitchen, Garden & Pets      2361574.40  1817723.12       543851.28
# 10    Snacks & Branded Foods       396141.50   364675.08        31466.42
#
#     Disount Percent
# 0         10.357351
# 1          9.550570
# 2         15.145428
# ...

# %%
## Bar plot to show category-wise Discount
a =sns.barplot(y=Dis.category,x=Dis['Disount Percent'])
a.bar_label(a.containers[0])
plt.title('Category wise Discount')
# Out:
# Text(0.5, 1.0, 'Category wise Discount')

# %% [markdown]
# ### **Top 10 Products by Market Price:**

# %%
# Bar plot to display the top 10 products by market price
top_products = df.nlargest(10, 'market_price')
plt.figure(figsize=(12, 6))
sns.barplot(x='market_price', y='product', data=top_products)
plt.title('Top 10 Products by Market Price')
plt.xlabel('Market Price')
plt.ylabel('Product')
plt.show()

# %% [markdown]
# ### **Correlation Matrix for Numerical Variables:**

# %%
# Select only numeric columns for correlation calculation
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Calculate the correlation matrix for numeric variables
correlation_matrix = df[numeric_columns].corr()

# Heatmap to visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix for Numeric Variables')
plt.show()

# %% [markdown]
# ### Total Revenue by Category and Subcategory:
#
# * Baby Care Dominance: 'Diapers & Wipes' and 'Baby Bath & Hygiene' lead in 'Baby Care,' contributing significantly to total revenue.
# * Diverse Bakery and Dairy: 'Bakery, Cakes & Dairy' displays sales diversity with various sub-categories.
# * Health and Beauty Market Strength: 'Fragrances & Deos,' 'Skin Care,' and 'Hair Care' are standout performers in 'Beauty & Hygiene.'
# * Gourmet & World Food Dynamics: Diverse offerings in 'Drinks & Beverages,' 'Sauces, Spreads & Dips,' and 'Snacks, Dry Fruits, Nuts.'
# * Kitchen and Garden Essentials: High-value segments include 'Cookware & Non Stick' and 'Crockery & Cutlery.'
# * Skincare Offerings: 'Skin Care' stands out with a remarkable variety of 2294 categories.
# * Fragrances & Deos Popularity: 'Fragrances & Deos' resonate strongly with 1133 categories.
# * Kitchen and Dining Essentials: Abundance in 'Crockery & Cutlery' and 'Cookware & Non Stick' sub-categories.
#
# ### Discount Analysis:
#
# * Discount Percentage by Category: Ranges from 7.94% to 23.03%, with 'Kitchen, Garden & Pets' having the highest.
# * Discount Price Distribution: 'Beauty & Hygiene' sees the highest discount, while 'Gourmet & World Food' and 'Snacks & Branded Foods' have lower discounts.
#
# ### Average Rating by Category:
#
# * Rating Averages: Range from 3.84 to 4.10, with 'Kitchen, Garden & Pets' having the lowest and * 'Eggs, Meat & Fish' and 'Fruits & Vegetables' the highest.
#
# ### Original vs. Sale vs. Discount Price:
#
# * Discount Price Impact: Highest in 'Beauty & Hygiene' and 'Kitchen, Garden & Pets,' indicating potential customer engagement.
# * Discount Percentage: Varied across categories, with 'Fruits & Vegetables' experiencing a notable 21.02% discount.
#
# ### Recommendations:
#
# * Category Expansion: Explore expanding product range in high-performing sub-categories, especially in 'Baby Care.'
# * Marketing Strategies: Tailor marketing strategies for diverse products in 'Bakery, Cakes & Dairy.'
# * Promotions in Health and Beauty: Capitalize on strong performers in 'Beauty & Hygiene' through targeted promotions.
# * Innovation in Gourmet & World Food: Introduce new global flavors or specialty items in response to market trends.
# * Premium Kitchen and Garden Products: Consider expanding offerings in 'Kitchen, Garden & Pets,' targeting premium or specialized items.
# * Customer Engagement in Skincare: Leverage the extensive variety in 'Skin Care' to enhance customer engagement.
# * Discount Optimization: Optimize discount strategies, especially in categories with lower discounts, to boost sales.
# * Rating Improvement: Focus on improving ratings, particularly in 'Kitchen, Garden & Pets,' for enhanced customer satisfaction.

# %%
df.to_csv('BigBasketFF', index=False)
